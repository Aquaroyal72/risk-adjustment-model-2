# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
individual_data = pd.read_csv("Data/individualPLRSdata.csv")
smallgroup_data = pd.read_csv("Data/smallgroupPLRSdata.csv")

# %%
individual_data.head()
# Out:
#   State  STATE AVERAGE MONTHLY PREMIUMS 2016  \
# 0    AK                           871.217683
# 1    AL                           408.031627
# 2    AR                           369.248837
# 3    AZ                           321.389994
# 4    CA                           393.250897
#
#    STATE AVERAGE PLAN LIABILITY RISK SCORE 2016  \
# 0                                      1.470562
# 1                                      2.009259
# 2                                      2.051508
# 3                                      1.518572
# 4                                      1.354745
#
#    STATE AVERAGE ALLOWABLE RATING FACTOR 2016  \
# 0                                    1.618582
# 1                                    1.594929
# 2                                    1.483455
# 3                                    1.539869
# 4                                    1.570077
#
#    STATE AVERAGE ACTUARIAL VALUE 2016  STATE INDUCED DEMAND FACTOR 2016  \
# ...

# %%
smallgroup_data.head()
# Out:
#   State  STATE AVERAGE MONTHLY PREMIUMS 2016  \
# 0    AK                           668.908273
# 1    AL                           412.511731
# 2    AR                           383.752717
# 3    AZ                           373.997888
# 4    CA                           434.423813
#
#    STATE AVERAGE PLAN LIABILITY RISK SCORE 2016  \
# 0                                      1.122278
# 1                                      1.573861
# 2                                      1.367362
# 3                                      1.220521
# 4                                      1.159441
#
#    STATE AVERAGE ALLOWABLE RATING FACTOR 2016  \
# 0                                    1.416341
# 1                                    1.463283
# 2                                    1.410754
# 3                                    1.367500
# 4                                    1.368486
#
#    STATE AVERAGE ACTUARIAL VALUE 2016  STATE INDUCED DEMAND FACTOR 2016  \
# ...

# %%
plt.hist(individual_data["STATE AVERAGE PLAN LIABILITY RISK SCORE DIFFERENCE"], 25, facecolor='g')


plt.xlabel('PLRS Difference')
plt.title('Individual Group State Average PLRS Difference between 2016 and 2015 BY')
plt.grid(True)
plt.show()

# %%
plt.hist(smallgroup_data["STATE AVERAGE PLAN LIABILITY RISK SCORE DIFFERENCE"], 25, facecolor='g')


plt.xlabel('PLRS Difference')
plt.title('Small Group State Average PLRS Difference between 2016 and 2015 BY')
plt.grid(True)
plt.show()
